# %%
import pandas as pd

# %%
anime = pd.read_csv( "../archive/anime.csv" )
anime
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
anime.dtypes
# Out:
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %% [markdown]
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %%
all(all(anime[x].isnull()) for x in anime.columns.tolist())
# Out:
# False

# %%
anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
anime.loc[:, 'name':'name']
# Out:
#                                                     name
# 0                                         Kimi no Na wa.
# 1                       Fullmetal Alchemist: Brotherhood
# 2                                               Gintama°
# 3                                            Steins;Gate
# 4                                          Gintama&#039;
# ...                                                  ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami
# 12290                                        Under World
# 12291                     Violence Gekiga David no Hoshi
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293                   Yasuji no Pornorama: Yacchimae!!
#
# [12294 rows x 1 columns]

# %%
anime[(anime["type"] == "Movie") & ((anime["rating"] >= 7.00) | (anime["anime_id"] % 10 == 0))]
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 8         15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 11        28851                                     Koe no Katachi
# 15          199                      Sen to Chihiro no Kamikakushi
# 18        12355                       Ookami Kodomo no Ame to Yuki
# ...         ...                                                ...
# 11035     32900  Mahouka Koukou no Rettousei Movie: Hoshi wo Yo...
# 11086     34310  Tamagotchi Movie: Tanpen Himitsu no Otodoke Da...
# 11113     33390                                      Zunda Horizon
# 11154      3220                            Kanashimi no Belladonna
# 11665      2360                   Choujin Densetsu Urotsukidouji 2
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
anime.loc[lambda anime: (anime["rating"] >= 7.00) & (anime["type"] == "Movie")]
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 8         15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 11        28851                                     Koe no Katachi
# 15          199                      Sen to Chihiro no Kamikakushi
# 18        12355                       Ookami Kodomo no Ame to Yuki
# ...         ...                                                ...
# 10767     32751                                      Xiao Men Shen
# 10833     21129                          Youtai Nuhai Zai Shanghai
# 10842     23345                               Yukiguni no Oujisama
# 10844     33828  Yume Kakeru Kougen: Kiyosato no Chichi Paul Rusch
# 11154      3220                            Kanashimi no Belladonna
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
anime.groupby(["type"])[["members"]].mean()
# Out:
#               members
# type
# Movie    10360.340716
# Music     1311.840164
# ONA       4114.030349
# OVA       5986.139837
# Special   7676.060859
# TV       42683.658305

# %%
rating = pd.read_csv("../archive/rating.csv")
rating
# Out:
#          user_id  anime_id  rating
# 0              1        20      -1
# 1              1        24      -1
# 2              1        79      -1
# 3              1       226      -1
# 4              1       241      -1
# ...          ...       ...     ...
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9
#
# [7813737 rows x 3 columns]

# %%
anime.merge(rating, how = "inner", left_on = "anime_id", right_on = "anime_id")
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 4           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 7813722      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813723      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813724      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7813725     26081                   Yasuji no Pornorama: Yacchimae!!
# 7813726     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                         genre   type episodes  rating_x  \
# ...

# %%
anime.merge(rating, how = "left", left_on = "anime_id", right_on = "anime_id")
# Out:
#          anime_id                                               name  \
# 0           32281                                     Kimi no Na wa.
# 1           32281                                     Kimi no Na wa.
# 2           32281                                     Kimi no Na wa.
# 3           32281                                     Kimi no Na wa.
# 4           32281                                     Kimi no Na wa.
# ...           ...                                                ...
# 7814819      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7814820      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7814821      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 7814822     26081                   Yasuji no Pornorama: Yacchimae!!
# 7814823     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                         genre   type episodes  rating_x  \
# ...

# %%
anime.merge(rating, how = "right", left_on = "anime_id", right_on = "anime_id")
# Out:
#          anime_id                                             name  \
# 0              20                                           Naruto
# 1              24                                    School Rumble
# 2              79                                         Shuffle!
# 3             226                                       Elfen Lied
# 4             241                        Girls Bravo: First Season
# ...           ...                                              ...
# 7813732     16512                   Devil Survivor 2 The Animation
# 7813733     17187  Ghost in the Shell: Arise - Border:1 Ghost Pain
# 7813734     22145                     Kuroshitsuji: Book of Circus
# 7813735       790                                       Ergo Proxy
# 7813736      8074                           Highschool of the Dead
#
#                                                      genre   type episodes  \
# 0        Action, Comedy, Martial Arts, Shounen, Super P...     TV      220
# ...
